# %%
# %pylab inline
from scipy.interpolate import griddata
from netCDF4 import Dataset
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python2.7/dist-packages/pkg_resources.py:1049: UserWarning: /home/alvise/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).
#   warnings.warn(msg, UserWarning)

# %%
def func(x, y):
    return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2

# %%
grid_x, grid_y = np.mgrid[0:1:180, 0:1:90]

# %%
points = np.random.rand(1000, 2)
values = func(points[:,0], points[:,1])

# %%
nc = Dataset('air.mon.ltm.nc')
hola = nc.variables['air']
lons = nc.variables['lon']
lats = nc.variables['lat']

# %%
# I create a 2D function
def my_func(x, y):
    return exp(-((x-0.5)**2)/0.1) * cos(15.0*(y**2))

# %%
# show on 500 points
points = np.random.rand(500, 2)
values = my_func(points[:,0], points[:,1])

# %%
#here i define a dense grid in x-y with ranges [0,1], [0,1] to see the complete funcion
grid_x, grid_y = mgrid[0:1:200j, 0:1:200j]

# %%
imshow(my_func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plot(points[:,0], points[:,1], 'k.', ms=2, alpha = 0.8)

ax = axes()
ax.set_xlabel("$x$",fontsize=20)
ax.set_ylabel("$y$",fontsize=20)
ax.set_title("$\mathrm{my\ data,\ my\ function}$", fontsize=20)

# %%
from scipy.interpolate import griddata
grid_zA = griddata(points, values, (grid_x, grid_y), method='nearest')

# %%
grid_zA.T
# Out:
# array([[ 0.09489485,  0.09489485,  0.09489485, ...,  0.11356737,
#          0.11356737,  0.11356737],
#        [ 0.09489485,  0.09489485,  0.09489485, ...,  0.11356737,
#          0.11356737,  0.11356737],
#        [ 0.09489485,  0.09489485,  0.09489485, ...,  0.11356737,
#          0.11356737,  0.11356737],
#        ...,
#        [-0.06198865, -0.06198865, -0.06198865, ...,  0.08289056,
#          0.08289056,  0.08289056],
#        [-0.06198865, -0.06198865, -0.06198865, ...,  0.08289056,
#          0.08289056,  0.08289056],
#        [-0.06198865, -0.06198865, -0.06198865, ...,  0.08289056,
#          0.08289056,  0.08289056]])

# %%
imshow(grid_zA.T, extent=(0,1,0,1), origin='lower')
plot(points[:,0], points[:,1], 'k.', ms=2, alpha = 0.8)

ax = axes()
ax.set_xlabel("$x$",fontsize=20)
ax.set_ylabel("$y$",fontsize=20)
ax.set_title("$\mathrm{my\ data\, my\ nearest\ interpolation}$", fontsize=20)
