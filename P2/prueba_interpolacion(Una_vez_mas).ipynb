# %%
# %pylab inline
from scipy.interpolate import griddata
from netCDF4 import Dataset
# Out:
# WARNING: pylab import has clobbered these variables: ['griddata']
# `%matplotlib` prevents importing * from pylab and numpy
# /usr/lib/python2.7/dist-packages/pkg_resources.py:1049: UserWarning: /home/alvise/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).
#   warnings.warn(msg, UserWarning)
# Populating the interactive namespace from numpy and matplotlib

# %%
def func(x, y):
    return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2

# %%
grid_x, grid_y = np.mgrid[0:1:180, 0:1:90]

# %%
points = np.random.rand(1000, 2)
values = func(points[:,0], points[:,1])

# %%
nc = Dataset('air.mon.ltm.nc')
hola = nc.variables['air']
lons = nc.variables['lon']
lats = nc.variables['lat']

# %%
grid_z0 = griddata(len(lons), lons, (grid_x, grid_y), method='nearest')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-8cf7b758c065> in <module>()
# ----> 1 grid_z0 = griddata(len(lons), lons, (grid_x, grid_y), method='nearest')
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/ndgriddata.pyc in griddata(points, values, xi, method, fill_value, rescale)
#     200         return ip(xi)
#     201     elif method == 'nearest':
# --> 202         ip = NearestNDInterpolator(points, values, rescale=rescale)
#     203         return ip(xi)
#     204     elif method == 'linear':
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/ndgriddata.pyc in __init__(self, x, y, rescale)
#      54         NDInterpolatorBase.__init__(self, x, y, rescale=rescale,
#      55                                     need_contiguous=False,
# ---> 56                                     need_values=False)
#      57         self.tree = cKDTree(self.points)
#      58         self.values = y
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/interpnd.so in scipy.interpolate.interpnd.NDInterpolatorBase.__init__ (scipy/interpolate/interpnd.c:2301)()
#
# /usr/lib/python2.7/dist-packages/scipy/interpolate/interpnd.so in scipy.interpolate.interpnd.NDInterpolatorBase._check_init_shape (scipy/interpolate/interpnd.c:2965)()
#
# IndexError: tuple index out of range

# %%
import matplotlib.pyplot as plt
plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'k.', ms=1)
plt.title('Original')
plt.subplot(222)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.gcf().set_size_inches(12, 12)
plt.show()
